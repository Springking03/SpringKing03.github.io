# %% [markdown]
# #2 Bài tập lớn trí tuệ nhân tạo
# Nhóm thực hiện: Nhóm 4
# Thành viên:
# 1. Châu Minh Hoàng (Nhóm trưởng)
# 2. Nguyễn Xuân Hoàng
# 3. Hoàng Lâm Hùng
# 4. Lưu Hoàng Đông

# %% [markdown]
# #Đẩy thư mục lên GG Colab

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9f4ed038-97af-42d6-9fb3-3ffa59747c10" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9f4ed038-97af-42d6-9fb3-3ffa59747c10">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #Giải nén thư mục

# %%
import zipfile
import os

# Tên file zip (đã được upload từ trước)
zip_path = "/content/butterfly-classification.zip"

# Thư mục đích để giải nén
extract_path = "butterfly-data"
os.makedirs(extract_path, exist_ok=True)

# Giải nén
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ Giải nén thành công vào thư mục:", extract_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-0c1a020620b8> in <cell line: 0>()
#      10
#      11 # Giải nén
# ---> 12 with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#      13     zip_ref.extractall(extract_path)
#      14
#
# /usr/lib/python3.11/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1293             while True:
#    1294                 try:
# -> 1295                     self.fp = io.open(file, filemode)
#    1296                 except OSError:
#    1297                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/butterfly-classification.zip'

# %% [markdown]
# #Load dữ liệu

# %%
# !pip install tensorflow-io

# %%
# (Nếu chưa cài TensorFlow)
# !pip install tensorflow

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Cấu hình
IMAGE_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 10

# %%
training_data = preprocessing.image_dataset_from_directory(
    "/content/butterfly-data/butterfly-classification/train",  # Đường dẫn đến thư mục ảnh huấn luyện
    batch_size=BATCH_SIZE,                                     # Kích thước mỗi lô huấn luyện (ví dụ: 128 ảnh/lô)
    image_size=(IMAGE_SIZE, IMAGE_SIZE),                       # Resize ảnh về kích thước 224x224
    shuffle=True                                               # Trộn ngẫu nhiên các ảnh
)

validation_data = preprocessing.image_dataset_from_directory(
    "/content/butterfly-data/butterfly-classification/test",   # Đường dẫn đến thư mục ảnh kiểm tra
    batch_size=BATCH_SIZE,                                     # Kích thước mỗi lô kiểm tra
    image_size=(IMAGE_SIZE, IMAGE_SIZE),                       # Resize ảnh về kích thước 224x224
    shuffle=True                                               # Trộn ngẫu nhiên các ảnh
)
